# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# # import tool

# %% [markdown]
# # import self-define tool

# %%
from module.OneOfFiveRule import class_OneOfFiveRule

# %% [markdown]
# # Problem 3

# %% [markdown]
# ## sigma = 0.01

# %%
for i in tqdm(range(10)):
    print("\nRun %d Start:" % (i+1))
    func = class_OneOfFiveRule(0.01)
    func.Minimization()
    print("fit Parent: %s" % func.result)
    print("fit value: %.6f" % func.result_fit)
    print("iteration: %d" % func.time)
# Out:
#   0%|                                                                                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                                                                        | 411/10000000 [00:00<06:52, 24244.19it/s]
#
#   0%|                                                                                                                                        | 915/10000000 [00:00<06:21, 26213.86it/s]
#
#   0%|                                                                                                                                        | 888/10000000 [00:00<05:36, 29679.04it/s]
#
#   0%|                                                                                                                                       | 1374/10000000 [00:00<05:33, 29950.13it/s]
#  40%|██████████████████████████████████████████████████████████▊                                                                                        | 4/10 [00:00<00:00, 29.28it/s]
#   0%|                                                                                                                                        | 967/10000000 [00:00<04:38, 35912.55it/s]
#
#   0%|                                                                                                                                                     | 0/10000000 [00:00<?, ?it/s]
# Run 1 Start:
# fit Parent: [-0.04703545099204123, -0.00619731863092897, -0.02509635073237292, -0.0023854927800422603, 0.017242258404614946, -0.02677970833894101, 0.023405452539942896, -0.017747364225090875, -0.005131719661077922, 0.0005346300020542612]
# fit value: 0.004790
# iteration: 411
#
# Run 2 Start:
# fit Parent: [-0.03085978744554146, 0.014360158970730131, 0.03453125132297733, 0.0068707346672326666, -0.01521820823007171, 0.027311414010644682, -0.019040126165191025, -0.021554871589242387, -0.005515161554637332, -0.026846729983023794]
# fit value: 0.004954
# iteration: 915
#
# Run 3 Start:
# fit Parent: [0.028815929231808566, -0.027302613969372076, 0.02355348050040941, 0.004579999587958816, -0.03258257672863198, -0.0011536620246197097, 0.00998725999369964, 0.02228278734096565, -0.003187597253926561, 0.019411198480056655]
# fit value: 0.004198
# iteration: 888
#
# Run 4 Start:
# fit Parent: [0.04742282395873261, -0.022551550392118012, -0.020258536930139757, -0.0074488325354265805, -0.013277697848979217, 0.02479049645474838, -0.002771927796769387, 0.010469068255234974, 0.020171849114907537, -0.017149038387943617]
# fit value: 0.004833
# iteration: 1374
#
# Run 5 Start:
# fit Parent: [0.0023365069272714015, 0.004098193170644398, 0.028086450657244983, 0.017845659180258145, 0.00015691165184749094, 0.01441588220962524, -0.013995925042517007, 0.036634573502891246, -0.03939189772768748, -0.02103722441355417]
# fit value: 0.004870
# iteration: 967
#
# Run 6 Start:
#   0%|                                                                                                                                        | 598/10000000 [00:00<05:25, 30739.55it/s]
#
#   0%|                                                                                                                                        | 607/10000000 [00:00<06:50, 24346.31it/s]
#
#   0%|                                                                                                                                        | 843/10000000 [00:00<05:43, 29147.76it/s]
#  80%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                             | 8/10 [00:00<00:00, 30.79it/s]
#   0%|                                                                                                                                        | 441/10000000 [00:00<04:31, 36850.78it/s]
#
#   0%|                                                                                                                                        | 989/10000000 [00:00<05:32, 30051.56it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 32.93it/s]
# fit Parent: [0.012518477298594946, 0.02824746473029444, -0.006189266293478302, -0.022062384523147027, -0.021567657155314147, 0.025880413656853923, -0.0004915435474651057, -0.0055738194303851935, -0.0051702928685899135, -0.04764491428273067]
# fit value: 0.004943
# iteration: 598
#
# Run 7 Start:
# fit Parent: [-0.004802763221461188, 0.01731656742456391, 0.03459181659659922, -0.023878967199132167, 0.005658831773297725, -0.007926277802881701, 0.03613090993096528, 0.03041426941214223, -0.015170327577949514, 0.016715543903840464]
# fit value: 0.004925
# iteration: 607
#
# Run 8 Start:
# fit Parent: [0.006519212555371018, 0.004242339181620802, 0.02706938459231642, 0.04125445772688526, -0.005663860862752093, 0.0077467403589533915, 0.010032478513283727, 0.005831520385328305, 0.03335889354603314, 0.01788180431635814]
# fit value: 0.004155
# iteration: 843
#
# Run 9 Start:
# fit Parent: [-0.00839653502569216, 0.014462981051620557, 0.040655338531331194, -0.03699842216705562, 0.021472382845500616, 0.002947037165991804, 0.011172290098410581, -0.009750859939384689, 0.019908932536748355, 0.019178257977567063]
# fit value: 0.004755
# iteration: 441
#
# Run 10 Start:
# fit Parent: [0.002474551293244521, 0.0026475433811979253, 0.005112823650850736, 0.024374436408026078, 0.02385031764130235, -0.024228556176299543, -0.006880489385751928, -0.04077492003534375, -0.011909829451851602, -0.03506863471090906]
# fit value: 0.004871
# iteration: 989

# %% [markdown]
# ## sigma = 0.1

# %%
for i in tqdm(range(10)):
    print("\nRun %d Start:" % (i+1))
    func = class_OneOfFiveRule(0.1)
    func.Minimization()
    print("fit Parent: %s" % func.result)
    print("fit value: %.6f" % func.result_fit)
    print("iteration: %d" % func.time)
# Out:
#   0%|                                                                                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                                                                        | 742/10000000 [00:00<07:50, 21257.14it/s]
#
#   0%|                                                                                                                                        | 255/10000000 [00:00<05:12, 31965.91it/s]
#
#   0%|                                                                                                                                                     | 0/10000000 [00:00<?, ?it/s]
# Run 1 Start:
# fit Parent: [0.029900882282073826, -0.010113790468095497, -0.011623779507504805, -0.01708455674038132, 0.039364120468679355, 0.01463754079395338, -0.028635132172518427, -0.0008288786318987815, -0.013845454295403339, -0.026652045978901764]
# fit value: 0.004910
# iteration: 742
#
# Run 2 Start:
# fit Parent: [-0.011046864570304259, 0.043742857542289994, 0.020588607866686513, -0.00029870372895366825, -0.012161979718433993, -0.017601076710319193, -0.03446555420901726, -0.018324432070602074, 0.0017222033442912488, 0.007320188787375002]
# fit value: 0.004497
# iteration: 255
#
# Run 3 Start:
#   0%|                                                                                                                                        | 257/10000000 [00:00<05:10, 32216.63it/s]
#
#   0%|                                                                                                                                        | 663/10000000 [00:00<05:15, 31656.75it/s]
#
#   0%|                                                                                                                                        | 397/10000000 [00:00<04:36, 36189.23it/s]
#
#   0%|                                                                                                                                        | 535/10000000 [00:00<04:58, 33529.36it/s]
#  60%|████████████████████████████████████████████████████████████████████████████████████████▏                                                          | 6/10 [00:00<00:00, 50.13it/s]
#   0%|                                                                                                                                        | 597/10000000 [00:00<05:34, 29935.32it/s]
#
#   0%|                                                                                                                                        | 458/10000000 [00:00<03:59, 41756.14it/s]
#
#   0%|                                                                                                                                        | 370/10000000 [00:00<04:56, 33743.40it/s]
#
#   0%|                                                                                                                                        | 451/10000000 [00:00<04:25, 37690.15it/s]
# fit Parent: [-0.002016858581093897, 0.0032864174197978564, 0.030930040703819797, -0.026956701466590266, 0.013054299400209024, 0.04594170546026724, -0.020769109405935623, -0.005177604797547853, 0.011605068221010005, 0.01696686620414155]
# fit value: 0.004860
# iteration: 257
#
# Run 4 Start:
# fit Parent: [0.025658216936654692, -0.01868930901443099, 0.01165232274128375, -0.00043504922493593816, -0.019813024604662312, -0.035390561790438715, 0.01013520379079784, -0.04082630657251055, -0.006231586357071361, 0.007537617867447225]
# fit value: 0.004654
# iteration: 663
#
# Run 5 Start:
# fit Parent: [0.03270103125075443, -0.0043671135990874035, 0.019345944142056842, 0.02721500241869359, -0.02592518021515604, 0.03343733294181167, 0.01247441483534274, -0.007292700015675863, -0.002782345445418031, -0.015172385340835731]
# fit value: 0.004440
# iteration: 397
#
# Run 6 Start:
# fit Parent: [-0.022056602625427812, -0.013627858460392907, -0.03350448423241965, 0.01632955625587018, -0.00280742163742706, -0.026649008458472123, 0.001380733549860443, -0.03892811640227098, -0.0038380209453117192, -0.0047309399489067205]
# fit value: 0.004334
# iteration: 535
#
# Run 7 Start:
# fit Parent: [-0.043945300926606375, 0.010086505629154228, -0.0024138426807561457, -0.02456009440130251, 0.0032292994122615206, -0.02253318294695852, 0.023392758645318968, -0.02752960320746712, -0.0037747509012248156, 0.022542319960567523]
# fit value: 0.004988
# iteration: 597
#
# Run 8 Start:
# fit Parent: [-0.008986786561569031, -0.02345167904033884, 0.0007579951687763722, -0.010743180310953197, 0.006670220928740125, 0.003928412653853779, -0.02504744776711644, 0.04426190164808007, 0.01083373844387903, 0.027238533372855818]
# fit value: 0.004252
# iteration: 458
#
# Run 9 Start:
# fit Parent: [0.01901925722447871, -0.0016129408381332262, 0.04643156192304551, -0.007765930341648312, 0.010792397397733756, 0.028488689856946588, -0.024666497521952397, 0.010704157944543987, -0.0038823773917213457, -0.018632993920188072]
# fit value: 0.004594
# iteration: 370
#
# Run 10 Start:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 53.33it/s]
# fit Parent: [-0.02901033605698186, -0.011309742897584362, 0.00814995578898728, -0.018402562956575302, -0.014446482078907929, -0.039001262949844046, 0.0015689034678694484, 0.016260774569517432, -0.03237685207634584, 0.01653529697973899]
# fit value: 0.004693
# iteration: 451

# %%
for i in tqdm(range(10)):
    print("\nRun %d Start:" % (i+1))
    func = class_OneOfFiveRule(1)
    func.Minimization()
    print("fit Parent: %s" % func.result)
    print("fit value: %.6f" % func.result_fit)
    print("iteration: %d" % func.time)
# Out:
#   0%|                                                                                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                                                                       | 1180/10000000 [00:00<07:19, 22753.21it/s]
# Run 1 Start:
#   0%|                                                                                                                                       | 1001/10000000 [00:00<05:58, 27881.07it/s]
#
#   0%|                                                                                                                                        | 373/10000000 [00:00<15:35, 10686.38it/s]
#  30%|████████████████████████████████████████████                                                                                                       | 3/10 [00:00<00:00, 21.89it/s]
#   0%|                                                                                                                                                     | 0/10000000 [00:00<?, ?it/s]
# fit Parent: [-0.029900358587848484, 0.012098064677131412, -0.015351545211260746, 0.014319083832032436, 0.016123695912815567, -0.024537864766875733, 0.007998269816489182, -0.009154107586010733, 0.03580280803960102, -0.00951165498266367]
# fit value: 0.003863
# iteration: 1180
#
# Run 2 Start:
# fit Parent: [-0.020505390557747773, -0.004631426247778819, -0.04173604606510241, 0.013737756531912605, 0.008315707747128205, -0.01811894950580062, 0.016756368501578613, -0.01204857767571169, -0.01900889091206618, -0.0047690519906172495]
# fit value: 0.003580
# iteration: 1001
#
# Run 3 Start:
# fit Parent: [-0.012748843535859831, 0.02797348476231172, 0.04003913404364411, 0.017067294967775655, 0.005708059905931319, 0.014214664173267179, -0.02476309157089589, -0.0002121160508038733, -0.031837514883520344, -0.01239270712784863]
# fit value: 0.004855
# iteration: 373
#
# Run 4 Start:
#   0%|                                                                                                                                        | 513/10000000 [00:00<13:17, 12545.79it/s]
#
#   0%|                                                                                                                                        | 324/10000000 [00:00<04:06, 40616.73it/s]
#
#   0%|                                                                                                                                        | 377/10000000 [00:00<04:37, 35971.08it/s]
#
#   0%|                                                                                                                                        | 349/10000000 [00:00<06:11, 26934.06it/s]
#
#   0%|                                                                                                                                        | 374/10000000 [00:00<07:59, 20843.89it/s]
#  80%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                             | 8/10 [00:00<00:00, 25.83it/s]
#   0%|                                                                                                                                        | 329/10000000 [00:00<07:04, 23565.12it/s]
#
#   0%|                                                                                                                                                     | 0/10000000 [00:00<?, ?it/s]
# fit Parent: [0.020309307997382602, -0.017324218826082254, 0.035846784522141045, 0.030707835140842993, 0.007028487369548321, 0.028658551570303316, 0.01922649185758673, -0.008629950798501632, -0.01074855884262044, 0.021837282934284826]
# fit value: 0.004848
# iteration: 513
#
# Run 5 Start:
# fit Parent: [0.03315536144234141, -0.01718561920271891, -0.0045703050785700985, 0.019439166649481338, -0.01566928144663643, -0.005802307390792728, -0.01562724306527903, -0.0327187690725108, -0.018972149128015765, -6.388630641008392e-05]
# fit value: 0.003747
# iteration: 324
#
# Run 6 Start:
# fit Parent: [-0.030078014888018714, 0.013614841573864101, -0.013357054710843714, 0.02984426312652214, -0.011871980125489701, 0.016000656631823273, -0.027601328920215513, 0.011789750389043108, 0.02373102724654412, 0.028727426387310077]
# fit value: 0.004845
# iteration: 377
#
# Run 7 Start:
# fit Parent: [-0.01337458900840452, -0.012813266303601398, -0.03757939020263993, -0.009728465824867244, 0.016488355835141744, -0.029670337222017652, 0.00419465822142171, -0.021699683119393368, 0.01916108870066456, 0.033047432291448145]
# fit value: 0.004950
# iteration: 349
#
# Run 8 Start:
# fit Parent: [0.028998778902046198, -0.006123137824806313, -0.03763280638381191, 0.01971462051930732, -0.01339830466125839, -0.015818608059635204, -0.01819649938553223, 0.03192746285178383, 0.014620403055810036, 0.014114401928557455]
# fit value: 0.004877
# iteration: 374
#
# Run 9 Start:
# fit Parent: [0.03140402446578789, 0.009435341248095825, 0.0030084115088552226, -0.0038589004561354855, 0.005134689645524306, -0.03352000048957861, 0.01431695341542421, -0.03319799598436692, 0.0349476987348972, -0.008925626910037052]
# fit value: 0.004857
# iteration: 329
#
# Run 10 Start:
#   0%|                                                                                                                                         | 388/10000000 [00:00<17:08, 9725.92it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 32.15it/s]
# fit Parent: [-0.024144515558611898, -0.017896937577018886, -0.03520040248333103, -0.02707647434569442, -0.026479316648347198, -0.011358649290341392, -0.016987699904704563, 0.003438324264705992, -0.018714529970547348, -0.022882027001500663]
# fit value: 0.004880
# iteration: 388
