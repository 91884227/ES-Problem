# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# # import tool

# %% [markdown]
# # import self-define tool

# %%
from module.OneOfFiveRule import class_OneOfFiveRule

# %% [markdown]
# # Problem 3

# %% [markdown]
# ## sigma = 0.01

# %%
for i in tqdm(range(10)):
    print("\nRun %d Start:" % (i+1))
    func = class_OneOfFiveRule(0.01)
    func.Minimization()
    print("fit Parent: %s" % func.result)
    print("fit value: %.6f" % func.result_fit)
    print("iteration: %d" % func.time)
# Out:
#  40%|█████████████████████████████████▏                                                 | 4/10 [00:00<00:00, 34.13it/s]
# Run 1 Start:
# fit Parent: [-0.008457252737274353, -0.02111089852081083, -0.03750136015225433, -0.02001555244934916, -0.0016797261621806976, 0.017907645220135274, 0.03686092994612381, 0.019834067836518473, -0.008801140291830788, -0.0098633209303417]
# fit value: 0.004575
# iteration: 808
#
# Run 2 Start:
# fit Parent: [0.003115602386848708, -0.020462406939687258, 0.0007871819165415662, -0.023907405125085754, -0.0004906759000845203, 0.041899995534448696, 0.015642260963042925, 0.007295535545461002, -0.01699988865373883, 0.02116489072895332]
# fit value: 0.003791
# iteration: 1257
#
# Run 3 Start:
# fit Parent: [-0.005094614345246442, -0.010929658169944591, 0.0188262912042673, 0.004287671867189913, 0.01806265730046398, -0.0023446141917756007, -0.0031002337008107957, -0.001788443387215349, -0.002606097855479603, 0.05507308873268031]
# fit value: 0.003903
# iteration: 840
#
# Run 4 Start:
# fit Parent: [-0.0004962580167791261, 0.009596956339274446, 0.005562181224955855, 0.024639780753787224, 0.00020054175550282115, 0.006975624964252809, -0.0021869535585223084, -0.024205790688078245, -0.03186038843891276, -0.03857392439091015]
# fit value: 0.003873
# iteration: 964
#
# Run 5 Start:
# fit Parent: [-0.01910265478213575, -0.0035391653706524236, -0.02047055020148405, -0.001718835668725327, 0.055096728977854705, 0.004516730565087398, -0.0047242396898118655, 0.00626345392228685, 0.032409095738269264, -0.00020848308310815803]
# fit value: 0.004967
# iteration: 649
#
# Run 6 Start:
# fit Parent: [0.019303225806319952, -0.02708861097417353, 0.01575529551140635, 0.028696605133002935, 0.011058669426248151, -0.0003636831618021377, -0.03745352917265288, 0.009991855816353486, 0.022354169523980602, -0.011133023094590926]
# fit value: 0.004427
# iteration: 1628
#
# Run 7 Start:
# fit Parent: [-0.01449834872243759, 0.0005516168460358573, 0.0372116342271778, 0.0037319757530010003, -0.002562048346616273, 0.012366598958034533, 0.023476590324649414, -0.04430238398637784, -0.00420718367048923, -0.0003548941573274112]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 33.87it/s]
# fit value: 0.004300
# iteration: 542
#
# Run 8 Start:
# fit Parent: [0.01998131264591164, 0.016620732548637163, 0.023027825229794092, 0.008576193831995222, 0.023700472925300517, -0.011876413965777124, 0.004421420157540984, 0.00990652742375324, 0.04600083707718471, 0.0009219226059100716]
# fit value: 0.004217
# iteration: 998
#
# Run 9 Start:
# fit Parent: [0.02284322020711472, -0.00811547109320057, -0.0033845499232966307, -0.008685349427625794, -0.048932398689701805, 0.01886117362542356, 0.004331479024736783, 0.017719917599749602, 8.178956280106728e-05, -0.034011411031359115]
# fit value: 0.004914
# iteration: 567
#
# Run 10 Start:
# fit Parent: [-0.015257679054619397, -0.016595566121177425, 0.006650343767279306, 0.010969831104556951, -0.046513954287041206, 0.02480056549914907, 0.019139528683253915, -0.016716773679169, 0.010491432078252445, -0.014581476519203218]
# fit value: 0.004420
# iteration: 1284

# %% [markdown]
# ## sigma = 0.1

# %%
for i in tqdm(range(10)):
    print("\nRun %d Start:" % (i+1))
    func = class_OneOfFiveRule(0.1)
    func.Minimization()
    print("fit Parent: %s" % func.result)
    print("fit value: %.6f" % func.result_fit)
    print("iteration: %d" % func.time)
# Out:
#  50%|█████████████████████████████████████████▌                                         | 5/10 [00:00<00:00, 36.30it/s]
# Run 1 Start:
# fit Parent: [0.016224358095639053, -0.004680041348888677, 0.024362962053876232, 0.002678048050214638, -0.011178879063572528, 0.014519104923215174, -0.03123013226088704, -0.017360111363210994, -0.003868524170190392, -0.048106753597310495]
# fit value: 0.004828
# iteration: 427
#
# Run 2 Start:
# fit Parent: [0.002661910956676495, 0.005633322883679046, -0.011591875519638676, 0.03351473606861361, -0.033410762126452734, -0.005782494668687474, 0.036240694098367346, -0.007066018642631391, -0.004152446061816677, 0.023430102474806834]
# fit value: 0.004376
# iteration: 593
#
# Run 3 Start:
# fit Parent: [0.03134222117454184, 0.009681688811763955, 0.0045194754410618895, -0.021602443059158954, 0.008521277133503292, 0.02132615269786238, -0.004908329436220882, -0.00236127873568686, -0.019098052703990915, -0.03146980372137101]
# fit value: 0.003475
# iteration: 526
#
# Run 4 Start:
# fit Parent: [-0.036460370530070285, 0.014605693078093899, 0.011812586362536936, 0.0180689989140944, 0.011690440688975803, 0.008853633688586706, -0.02822233531408991, -0.009012428303515091, 0.021486917252135515, -0.03194280722171738]
# fit value: 0.004584
# iteration: 253
#
# Run 5 Start:
# fit Parent: [-0.013338561876383288, -0.017163084496444353, -0.023363333340723203, -0.011517004216313626, -0.03581537608653093, 0.026351729409941446, -0.03378605556306759, 0.013490454947683434, -0.01775733453746297, -0.012411778052256135]
# fit value: 0.004921
# iteration: 1542
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 37.66it/s]
# Run 6 Start:
# fit Parent: [-0.01751566654576683, 0.01732392488507955, 0.02480008436894941, -0.032544897628573356, -0.00255077493915168, 0.026407393949218354, -0.006070879333319317, -0.008687320719862487, 0.02241044598471905, 0.016719125714763944]
# fit value: 0.003879
# iteration: 638
#
# Run 7 Start:
# fit Parent: [0.005391907249754017, -0.008589945922375958, -0.018193864693963797, -0.05399629254469335, 0.02986490727224872, 0.016120411777178066, -0.010761756188962326, -0.009796913918733004, -0.0066551644433069865, -0.008500786716235307]
# fit value: 0.004830
# iteration: 554
#
# Run 8 Start:
# fit Parent: [0.026603732286589597, -0.038627666757844153, 0.006516443671621089, -0.023805149417684246, -0.0010757025839378625, -0.012645779948302495, -0.0008671731979537109, 0.006267016348811498, 0.02646846956575117, 0.0044576699624732105]
# fit value: 0.003731
# iteration: 480
#
# Run 9 Start:
# fit Parent: [0.0037887481598328637, 0.013272011783574171, 0.00612403586861659, 0.0210710767038962, 0.021778790469587445, -0.031039828669442417, 0.010518013420682234, -0.01484400245649314, 0.039593424555373846, 0.026386028118151272]
# fit value: 0.004705
# iteration: 579
#
# Run 10 Start:
# fit Parent: [-0.039972396978484155, -0.0262410487251169, 0.026402929595386294, -0.001282675920989663, 0.015565204896024736, -0.010788937090139904, 0.012015095838336941, -0.010723748576011972, -0.013898124436392866, -0.02675699278524507]
# fit value: 0.004512
# iteration: 1020
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 38.47it/s]

# %%
for i in tqdm(range(10)):
    print("\nRun %d Start:" % (i+1))
    func = class_OneOfFiveRule(1)
    func.Minimization()
    print("fit Parent: %s" % func.result)
    print("fit value: %.6f" % func.result_fit)
    print("iteration: %d" % func.time)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 59.33it/s]
# Run 1 Start:
# fit Parent: [0.016179543279131608, -0.0007529522749473508, 0.012790633354728981, 0.018064328005958353, -0.02175332870848072, -0.03906596197295151, -0.0100947384680887, -0.010084916163125512, 0.03766507487774118, -0.02046284108824587]
# fit value: 0.004793
# iteration: 328
#
# Run 2 Start:
# fit Parent: [-0.013124244178280427, 0.028665529643035564, 0.02619778440989127, 0.008333909725118332, -0.010955717304648269, 0.01483290051891262, -0.029565127682925078, 0.036590075405224395, -0.008913458362306503, -0.023421743387212444]
# fit value: 0.004931
# iteration: 234
#
# Run 3 Start:
# fit Parent: [0.02854593871156018, 0.013616128699901284, 0.03482711588443697, 0.044858074839393615, -0.00656821857616136, 0.008653759597439971, 0.003997622128213649, 0.0013893481874558446, 0.0019204153726455142, 0.018396175688837283]
# fit value: 0.004703
# iteration: 536
#
# Run 4 Start:
# fit Parent: [0.02936613362010504, 0.02827507738005531, 0.025306018540096346, 0.02526062728917388, 0.02303288576523034, 0.03305437066731716, 0.0028406319701155844, 0.014082638298026237, 0.0100208241937625, 0.010441229930495618]
# fit value: 0.004979
# iteration: 277
#
# Run 5 Start:
# fit Parent: [-0.02531523698893304, 0.023167921000220595, -0.02561743404851801, -0.029094519697176396, 0.029991654624935936, -0.015346689481251397, 0.02633127774709633, -0.0035395116648450375, -0.020636466453832564, 0.002068489881306092]
# fit value: 0.004951
# iteration: 242
#
# Run 6 Start:
# fit Parent: [-0.0031932510133657194, -0.02171179009525918, -0.03254213861948056, -0.0012113816598019397, -0.01595473273407212, 0.020585845810608232, 0.008211964978894652, 0.012416521194335664, 0.03937921861288546, 0.006350756530606988]
# fit value: 0.004033
# iteration: 396
#
# Run 7 Start:
# fit Parent: [0.015352511744872182, -0.01962362879269709, 0.0007200852606068117, -0.004620308493609822, -0.027595890268216468, 0.0056028353783287715, -0.018800184321058944, 0.04486756429525327, 0.03054364452051441, -0.013703824493801512]
# fit value: 0.004923
# iteration: 589
#
# Run 8 Start:
# fit Parent: [0.032006966908017354, -0.0032072758411204744, 0.015775008686626596, -0.022727296344980875, -0.003553605498150654, 0.008499885577494273, -0.010772637338673424, -0.0013746316091566794, -0.02672017554511402, -0.002693022889550983]
# fit value: 0.002724
# iteration: 314
#
# Run 9 Start:
# fit Parent: [-0.024443159312325727, 0.04269329574376028, -0.006663667279875623, 0.00031674799203285087, -0.003736670997296231, -0.017833909600025965, -0.0022670873430119982, -0.020250594090314225, 0.02886583766076985, 0.02883827340887115]
# fit value: 0.004877
# iteration: 650
#
# Run 10 Start:
# fit Parent: [0.02891623598278153, 0.00041928163861110505, 0.024843410497918435, -0.03802500811341457, -0.024375600811404375, 0.006344252124297567, 0.0013473019756631277, 0.0336978794563755, -0.010374066535565009, -0.01462449002948156]
# fit value: 0.004993
# iteration: 380
