# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# # import tool

# %% [markdown]
# # import self-define tool

# %%
from module.OnePlusOne import class_OnePlusOne

# %% [markdown]
# # Problem 3

# %% [markdown]
# ## sigma = 0.01

# %%
for i in tqdm(range(10)):
    print("\nRun %d Start:" % (i+1))
    func = class_OnePlusOne(0.01)
    func.Minimization()
    print("fit Parent: %s" % func.result)
    print("fit value: %.6f" % func.result_fit)
    print("iteration: %d" % func.time)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 44.86it/s]
# Run 1 Start:
# fit Parent: [0.002071461747652019, 0.027389761851987736, 0.01482285321662984, 0.021796163479889104, 0.03243801314183517, 0.022814631133759308, 0.015336129567547391, -0.012956868603535322, 0.03180996867281631, 0.017090594123360336]
# fit value: 0.004729
# iteration: 933
#
# Run 2 Start:
# fit Parent: [-0.012194087792136647, 0.00359569702920907, 0.04759343841201361, -0.0002385242447552182, -0.0107727319085823, 0.034125715851137876, 0.016270365712356107, 0.02583723463538084, -0.014203355419440903, -0.012575114947918423]
# fit value: 0.005000
# iteration: 861
#
# Run 3 Start:
# fit Parent: [-0.00954835547879589, 0.01710224989603709, 0.013244433579403723, -0.006645835927264549, -0.009704400315563688, 0.025515652447552856, 0.01014800209237203, -0.03941285228119801, 0.03390621060194647, 0.025736276182145464]
# fit value: 0.004817
# iteration: 851
#
# Run 4 Start:
# fit Parent: [0.005154152112980157, 0.00018463791336775087, 0.01631750612455504, -0.0008440709872425715, 0.00791797793962357, 0.024785671838557406, 0.024233154754793387, -0.012679123727488148, 0.03305396022281436, 0.04061632506121301]
# fit value: 0.004461
# iteration: 882
#
# Run 5 Start:
# fit Parent: [0.037654773336544316, 0.0005711797706596085, 0.02276538266149203, 0.026855400941629543, 0.0042901694615347305, 0.010074670589318789, -0.02434739532650939, -0.015935345528362316, 0.012278326631009659, 0.015032677454869761]
# fit value: 0.004001
# iteration: 856
#
# Run 6 Start:
# fit Parent: [0.02999599174736635, -0.013228178395978856, 0.01597324239035373, 0.02790569531579292, -0.0010371982106140952, 0.04648613476053403, 0.0032777294395612325, 0.0171794959677014, -0.003101453806092464, 0.0128144180266031]
# fit value: 0.004750
# iteration: 867
#
# Run 7 Start:
# fit Parent: [0.026473394888295716, 0.00801325840284411, -0.00031079649763555896, 0.03333207924722875, -0.034352225568760754, 0.034006988498917264, 0.009944684322296327, 0.005053942520998566, -0.013041391948950732, 0.006816131713541119]
# fit value: 0.004554
# iteration: 899
#
# Run 8 Start:
# fit Parent: [0.012680321770458924, 0.018502926599779253, 0.0025835184493234655, -0.008666231024905161, 0.01771703634999282, 0.00029623329620156666, 0.03179827109075337, -0.03925434405514618, 0.013259453386173979, 0.023586658623522796]
# fit value: 0.004183
# iteration: 785
#
# Run 9 Start:
# fit Parent: [-0.01175858130845877, 0.020577905669915818, -0.02295731675438798, 0.0005913808218902796, 0.04218077306436625, -0.011809155267891218, -0.010249972581115945, -0.001501097975064371, -0.0045154977222558075, 0.03698280044671928]
# fit value: 0.004503
# iteration: 797
#
# Run 10 Start:
# fit Parent: [-0.017632872628561502, 0.028197401375602234, -0.0016455529873988257, 0.022528686304064537, -0.01696246512938475, 0.04073095147890149, 0.002775961855866687, 0.026823054483975768, -0.01204111984203543, -0.0032374523653078678]
# fit value: 0.004446
# iteration: 921
# 100%|██████████| 10/10 [00:00<00:00, 45.06it/s]

# %%
func.Parent
# Out:
# [-0.017632872628561502,
#  0.028197401375602234,
#  -0.0016455529873988257,
#  0.022528686304064537,
#  -0.01696246512938475,
#  0.04073095147890149,
#  0.002775961855866687,
#  0.026823054483975768,
#  -0.01204111984203543,
#  -0.0032374523653078678]

# %%
func.fit_func(func.Parent)
# Out:
# 0.0044456487052788474

# %%
func.time
# Out:
# 921

# %% [markdown]
# ## sigma = 0.1

# %%
for i in tqdm(range(10)):
    print("\nRun %d Start:" % (i+1))
    func = class_OnePlusOne(0.1)
    func.Minimization()
    print("fit Parent: %s" % func.result)
    print("fit value: %.6f" % func.result_fit)
    print("iteration: %d" % func.time)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Run 1 Start:
#  10%|█         | 1/10 [00:09<01:24,  9.38s/it]
# fit Parent: [-0.024968387680589215, -0.026862738453268684, 0.01942208191412106, -0.0005045692925014084, 0.04357344478653691, -0.015066148699188816, -0.009484706441579092, -0.021775555638668946, -0.011981938371388084, 0.02057112512224614]
# fit value: 0.004979
# iteration: 400098
#
# Run 2 Start:
#  20%|██        | 2/10 [00:21<01:21, 10.23s/it]
# fit Parent: [0.007912113974972825, -0.010713026728174587, 0.0015059994639679882, -0.011534645784732034, 0.009072385629331835, -0.00959309049141351, -0.04326257331466007, -0.00856678805393115, 0.014869437657273173, 0.04432282018982458]
# fit value: 0.004618
# iteration: 527315
#
# Run 3 Start:
#  30%|███       | 3/10 [00:26<01:00,  8.62s/it]
# fit Parent: [0.031606353054135915, -0.00665646868461036, 0.005479392774531276, 0.011138031012210654, 0.013353052179775423, 0.01648894606436559, 0.013099915252262498, 0.01893897818058237, 0.012484606919865828, 0.04343660771321786]
# fit value: 0.004220
# iteration: 203047
#
# Run 4 Start:
# fit Parent: [0.007127079598361179, 0.022994014625582593, 0.00038183861078758957, 0.024197242900018706, -0.03994327074599198, -0.005388050602660697, 0.004074486724496208, -0.015708241861476235, -0.02898821991250901, -0.02345921609720885]
#  50%|█████     | 5/10 [00:34<00:32,  6.44s/it]
# fit value: 0.004444
# iteration: 70917
#
# Run 5 Start:
# fit Parent: [0.034083503439195875, 0.01964869332125472, -0.005130963213739178, -0.002121149217869935, -0.0038824782304959643, 0.01138887909183461, -0.029368204680330724, -0.013694277803843344, 0.019627149728937622, -0.03211025059950401]
# fit value: 0.004190
# iteration: 257324
#
# Run 6 Start:
#  60%|██████    | 6/10 [00:37<00:22,  5.55s/it]
# fit Parent: [-0.015453623994184144, 0.009878146709939015, 0.0048629600113504895, 0.0001481674128132049, -0.03862711447772971, -0.03138445437660295, 0.019987548425923544, 0.014275564966026739, 0.02164482231602724, 0.0027176261254634165]
# fit value: 0.003916
# iteration: 141141
#
# Run 7 Start:
#  70%|███████   | 7/10 [00:49<00:21,  7.29s/it]
# fit Parent: [0.007009542449977297, 0.02066756646263707, -0.014730616748325143, 0.02444435069590875, 0.012661023724169967, -0.031661468147191583, -0.005977742133598588, -0.01520559961393508, 0.020541690964304894, 0.01856109448461678]
# fit value: 0.003487
# iteration: 498805
#
# Run 8 Start:
#  80%|████████  | 8/10 [00:53<00:12,  6.30s/it]
# fit Parent: [0.007411834578434492, -0.04346849926537252, 0.013342251769886283, -0.022129582646173852, 0.000512506880490933, 0.0075928668013776155, -0.005437810283103424, 0.027130839453191023, -0.01959791717071191, -0.0016157487030667647]
# fit value: 0.003822
# iteration: 168163
#
# Run 9 Start:
# 100%|██████████| 10/10 [00:56<00:00,  3.86s/it]
# fit Parent: [0.019917582127628928, -0.0027308887102392553, 0.02149439324482444, 0.015415536049894795, 0.04116664461479211, -0.002851964139391785, -0.018365234093912927, 0.03786149553972034, 0.00765064632202235, 0.008996558103508544]
# fit value: 0.004717
# iteration: 123605
#
# Run 10 Start:
# fit Parent: [-0.020962532329582693, -0.02166799660637833, 0.02055178688953896, 0.02379581594534591, -0.020745533802182237, -0.01628571440346946, 0.008563059350150927, -0.03171080069708293, 0.01147415023792904, 0.010719772460607523]
# fit value: 0.003919
# iteration: 20310
# 100%|██████████| 10/10 [00:56<00:00,  5.66s/it]

# %%
for i in tqdm(range(10)):
    print("\nRun %d Start:" % (i+1))
    func = class_OnePlusOne(1)
    func.Minimization()
    print("fit Parent: %s" % func.result)
    print("fit value: %.6f" % func.result_fit)
    print("iteration: %d" % func.time)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Run 1 Start:
#  10%|█         | 1/10 [03:48<34:17, 228.64s/it]
# fit Parent: [-0.007237512583951104, 0.1321802893420831, 0.02045897744101975, 0.1855448274225456, 0.10104939191061536, -0.13806975644173972, -0.06066677455005254, -0.22571073328627342, -0.02318564258493164, 0.3050507881685564]
# fit value: 0.229863
# iteration: 10000000
#
# Run 2 Start:
#  20%|██        | 2/10 [07:38<30:31, 228.97s/it]
# fit Parent: [0.17598066038489724, 0.09563059585471592, -0.12668872708451495, -0.2001673712876431, 0.13327710547190993, -0.18521465645697396, -0.015717681488491037, 0.007231675121731507, -0.1307560042160293, -0.014441595261495757]
# fit value: 0.165904
# iteration: 10000000
#
# Run 3 Start:
#  30%|███       | 3/10 [11:23<26:35, 227.95s/it]
# fit Parent: [-0.1319001083528541, 0.12336230559141921, 0.07887970721778303, 0.18188823835172682, 0.09351463486374098, 0.0683953184252784, 0.3495257730738423, 0.046727527145588366, 0.05748718370799327, 0.045939126496297084]
# fit value: 0.215111
# iteration: 10000000
#
# Run 4 Start:
#  40%|████      | 4/10 [15:10<22:46, 227.67s/it]
# fit Parent: [-0.26186026097903703, -0.14766799168797207, -0.08236793362634863, -0.02544961736517737, 0.014367278913085202, -0.03474841265780712, 0.029631734679705007, 0.14906564432044733, -0.008815689355504384, 0.12024611540634855]
# fit value: 0.136858
# iteration: 10000000
#
# Run 5 Start:
#  50%|█████     | 5/10 [18:57<18:57, 227.42s/it]
# fit Parent: [0.09675512103953647, 0.005682031450887137, 0.253944596087323, 0.03329235960475327, -0.06997236314610977, -0.17509953159799457, 0.003635368320479504, 0.03323430695298024, 0.15081119109524202, 0.031089852891234365]
# fit value: 0.135374
# iteration: 10000000
#
# Run 6 Start:
#  60%|██████    | 6/10 [22:44<15:08, 227.21s/it]
# fit Parent: [-0.13019039390227632, -0.10242521737538032, 0.13333643373589407, -0.04848779284754359, -0.25247847784752125, -0.042327216698492376, 0.1430993917143148, 0.11160010719986177, -0.03849656424302039, -0.026275123986754995]
# fit value: 0.148211
# iteration: 10000000
#
# Run 7 Start:
#  70%|███████   | 7/10 [26:34<11:24, 228.11s/it]
# fit Parent: [0.20274723296334546, 0.0010598508564164666, -0.03182510537015465, -0.11561926724568773, 0.16129697233400586, 0.2304193769470987, -0.1175172454427918, -0.19819235632692878, 0.13667419738295392, 0.07976659900563918]
# fit value: 0.212731
# iteration: 10000000
#
# Run 8 Start:
#  80%|████████  | 8/10 [30:18<07:33, 226.95s/it]
# fit Parent: [-0.20439644811364688, 0.18759546237953748, 0.07382150591323063, 0.04317492636781736, -0.06558913826176592, -0.11857711248469871, -0.018328861284553688, 0.1813722474735291, -0.14942764233789319, -0.022366158417836873]
# fit value: 0.158707
# iteration: 10000000
#
# Run 9 Start:
#  90%|█████████ | 9/10 [34:04<03:46, 226.62s/it]
# fit Parent: [-0.10957846725663481, -0.009771838104002464, 0.15005301248418768, 0.1853705328844712, 0.0869999156104044, 0.04682224550339288, 0.01329787970412677, 0.08496687846312173, 0.07683620867463863, 0.2673164073091709]
# fit value: 0.163500
# iteration: 10000000
#
# Run 10 Start:
# 100%|██████████| 10/10 [37:55<00:00, 227.56s/it]
# fit Parent: [-0.054242670015676814, 0.04631954273675844, -0.06255959944703374, 0.016818665393777174, 0.010181400121164697, 0.2789540645647014, -0.17983512316277472, 0.22008313954656167, -0.18749851069523754, -0.27431285671707584]
# fit value: 0.278384
# iteration: 10000000
